# %%
# show result of last expression even if it was an assignment
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %% [markdown]
# # Step 1: The Station List

# %% [markdown]
# **Option 1:** Use the `gbfs-client` package to fetch the Greenbike GBFS feed: https://pypi.org/project/gbfs-client/

# %%
GBFS_URL = "https://gbfs.bcycle.com/bcycle_greenbikeslc/gbfs.json"
# Out:
# 'https://gbfs.bcycle.com/bcycle_greenbikeslc/gbfs.json'

# %%
from gbfs.client import GBFSClient
client = GBFSClient(GBFS_URL)
gbfs_stations = client.request_feed('station_information').get('data').get('stations')
# Out:
# [{'lon': -111.88774,
#   'lat': 40.76704,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2248&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2248&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '123 E 100 S',
#   'name': 'Harmons Station @ 123E 100S',
#   'station_id': 'bcycle_greenbikeslc_2248'},
#  {'lon': -111.89126,
#   'lat': 40.76903,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2251&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2251&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '6 S. Main St.',
#   'name': 'Key Bank Station @ 6S Main Street',
#   'station_id': 'bcycle_greenbikeslc_2251'},
#  {'lon': -111.89544,
#   'lat': 40.76266,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2252&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2252&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '147W Broadway',
#   'name': 'Squatters Station @ 147W Broadway',
#   'station_id': 'bcycle_greenbikeslc_2252'},
#  {'lon': -111.89419,
#   'lat': 40.76812,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2254&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2254&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '20 S West Temple',
#   'name': '20S West Temple Station',
#   'station_id': 'bcycle_greenbikeslc_2254'},
#  {'lon': -111.89091,
#   'lat': 40.76142,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2255&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2255&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '353S Main Street',
#   'name': 'City Weekly Station @ 353S Main Street',
#   'station_id': 'bcycle_greenbikeslc_2255'},
#  {'lon': -111.90274,
#   'lat': 40.76975,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2256&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2256&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '400 W South Temple',
#   'name': '400W South Temple Station',
#   'station_id': 'bcycle_greenbikeslc_2256'},
#  {'lon': -111.89095,
#   'lat': 40.7643,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2257&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2257&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '225 S. Main St.',
#   'name': 'Rocky Mountain Power Station @ 225S Main Street',
#   'station_id': 'bcycle_greenbikeslc_2257'},
#  {'lon': -111.89667,
#   'lat': 40.77181,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2258&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2258&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '200 West North Temple',
#   'name': 'The Church of Jesus Christ of Latter-Day Saints Station @ 200W North Temple',
#   'station_id': 'bcycle_greenbikeslc_2258'},
#  {'lon': -111.9085,
#   'lat': 40.76257,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2259&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2259&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '290S 600W',
#   'name': 'UTA Salt Lake Central Station @ 290S 600W',
#   'station_id': 'bcycle_greenbikeslc_2259'},
#  {'lon': -111.89707,
#   'lat': 40.76906,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2400&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2400&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '215 West South Temple',
#   'name': 'Radisson Station @ 215W South Temple',
#   'station_id': 'bcycle_greenbikeslc_2400'},
#  {'lon': -111.88521,
#   'lat': 40.75943,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2735&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2735&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '450 South 200 East',
#   'name': 'UCAIR Station @ 450S 200E',
#   'station_id': 'bcycle_greenbikeslc_2735'},
#  {'lon': -111.90874,
#   'lat': 40.77132,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2736&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2736&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '640 West North Temple',
#   'name': '640W  North Temple Station',
#   'station_id': 'bcycle_greenbikeslc_2736'},
#  {'lon': -111.89124,
#   'lat': 40.76624,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2737&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2737&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '136S Main Street ',
#   'name': 'Energy Development Station @ 136S Main Street',
#   'station_id': 'bcycle_greenbikeslc_2737'},
#  {'lon': -111.89593,
#   'lat': 40.75861,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2738&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2738&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '500S 150W',
#   'name': 'Sheraton Station @ 500S 150W',
#   'station_id': 'bcycle_greenbikeslc_2738'},
#  {'lon': -111.87982,
#   'lat': 40.76539,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2739&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2739&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '190 South 400 East',
#   'name': 'CityScape Station @ 190S 400E',
#   'station_id': 'bcycle_greenbikeslc_2739'},
#  {'lon': -111.88286,
#   'lat': 40.76297,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2740&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2740&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '300 South 300 East',
#   'name': '3 & 3 Uncommons Station ',
#   'station_id': 'bcycle_greenbikeslc_2740'},
#  {'lon': -111.89248,
#   'lat': 40.76283,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2742&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_2742&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '50 W 300 S',
#   'name': 'Twilight Concert Series Station @ 50W Broadway ',
#   'station_id': 'bcycle_greenbikeslc_2742'},
#  {'lon': -111.90006,
#   'lat': 40.76285,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3181&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3181&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '300S 300W',
#   'name': 'UCAIR Station @ Pioneer Park',
#   'station_id': 'bcycle_greenbikeslc_3181'},
#  {'lon': -111.88515,
#   'lat': 40.76524,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3182&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3182&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '200S 200E ',
#   'name': 'SLUG Mag Station @ 200S 200E',
#   'station_id': 'bcycle_greenbikeslc_3182'},
#  {'lon': -111.90424,
#   'lat': 40.76713,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3183&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3183&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '100S 469W',
#   'name': 'The Gateway Station @ 100S Rio Grande ',
#   'station_id': 'bcycle_greenbikeslc_3183'},
#  {'lon': -111.87664,
#   'lat': 40.76746,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3184&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3184&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': ' 100S 500E ',
#   'name': ' 100S 500E Station',
#   'station_id': 'bcycle_greenbikeslc_3184'},
#  {'lon': -111.87697,
#   'lat': 40.76307,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3185&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3185&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '300S 500E',
#   'name': 'JF Capital Station @ 300S 500E',
#   'station_id': 'bcycle_greenbikeslc_3185'},
#  {'lon': -111.89085,
#   'lat': 40.76732,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3423&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3423&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '100S Main St ',
#   'name': 'Dominion Energy Station @ 100S Main Street ',
#   'station_id': 'bcycle_greenbikeslc_3423'},
#  {'lon': -111.89659,
#   'lat': 40.76377,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3425&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3425&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '250S 200W ',
#   'name': '250S 200W Station',
#   'station_id': 'bcycle_greenbikeslc_3425'},
#  {'lon': -111.89817,
#   'lat': 40.76485,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3426&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3426&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '200S 250W',
#   'name': 'Milagro and AC Hotel Station @ 200S 250W',
#   'station_id': 'bcycle_greenbikeslc_3426'},
#  {'lon': -111.87152,
#   'lat': 40.75791,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3427&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3427&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '510S 700E',
#   'name': 'Salt Lake Mag Station @ 510S 700E (Trolley Square)',
#   'station_id': 'bcycle_greenbikeslc_3427'},
#  {'lon': -111.905,
#   'lat': 40.77187,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3428&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3428&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '500W N. Temple',
#   'name': 'UTA FrontRunner Station @ 500W North Temple',
#   'station_id': 'bcycle_greenbikeslc_3428'},
#  {'lon': -111.91133,
#   'lat': 40.76464,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3430&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3430&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '200S 669W',
#   'name': 'UTA FrontLines Station @ 200S 669W',
#   'station_id': 'bcycle_greenbikeslc_3430'},
#  {'lon': -111.90558,
#   'lat': 40.76474,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3847&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_3847&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '200 South 500 West',
#   'name': 'Artspace Bridge Station @ 200S 500W',
#   'station_id': 'bcycle_greenbikeslc_3847'},
#  {'lon': -111.89756,
#   'lat': 40.72529,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4524&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4524&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '2100 South 225 West',
#   'name': 'UTA Central Pointe Station @ 2100S 225W',
#   'station_id': 'bcycle_greenbikeslc_4524'},
#  {'lon': -111.88739,
#   'lat': 40.72739,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4525&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4525&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '2001 South State Street',
#   'name': 'Salt Lake County Station @ 2001S State Street',
#   'station_id': 'bcycle_greenbikeslc_4525'},
#  {'lon': -111.86563,
#   'lat': 40.74988,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4526&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4526&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '900 South 900 East',
#   'name': '9th & 9th Station',
#   'station_id': 'bcycle_greenbikeslc_4526'},
#  {'lon': -111.90271,
#   'lat': 40.75174,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4528&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4528&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '800 South 400 West',
#   'name': 'Artspace Commons Station @ 800S 400W',
#   'station_id': 'bcycle_greenbikeslc_4528'},
#  {'lon': -111.89094,
#   'lat': 40.75025,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4529&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4529&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '867 South Main Street',
#   'name': 'Proper Brewing Co Station @ 867S Main Street',
#   'station_id': 'bcycle_greenbikeslc_4529'},
#  {'lon': -111.90529,
#   'lat': 40.76833,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4530&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4530&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '50 South 500 West',
#   'name': '50S 500W Station',
#   'station_id': 'bcycle_greenbikeslc_4530'},
#  {'lon': -111.88244,
#   'lat': 40.7594,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4590&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4590&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '450 South 300 East',
#   'name': 'The Shop @ 450S 300E Station',
#   'station_id': 'bcycle_greenbikeslc_4590'},
#  {'lon': -111.90523,
#   'lat': 40.75689,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4591&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4591&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '580 South 500 West',
#   'name': 'EcoBox Station @ 580S 500W ',
#   'station_id': 'bcycle_greenbikeslc_4591'},
#  {'lon': -111.89126,
#   'lat': 40.77187,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4593&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4593&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '111 North Main Street',
#   'name': 'The Church of Jesus Christ of Latter-Day Saints Station @ 111N Main Street',
#   'station_id': 'bcycle_greenbikeslc_4593'},
#  {'lon': -111.87725,
#   'lat': 40.74991,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4594&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4594&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '900 South 490 East',
#   'name': '900S 490E Station',
#   'station_id': 'bcycle_greenbikeslc_4594'},
#  {'lon': -111.87053,
#   'lat': 40.76296,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4595&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4595&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '300 S 710 East',
#   'name': '300S 710E Station',
#   'station_id': 'bcycle_greenbikeslc_4595'},
#  {'lon': -111.88568,
#   'lat': 40.76265,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4603&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4603&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '300 south 200 east',
#   'name': '300S 200E Station',
#   'station_id': 'bcycle_greenbikeslc_4603'},
#  {'lon': -111.88511,
#   'lat': 40.76154,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4619&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_4619&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'address': '349S 200E',
#   'name': '349S 200E Station',
#   'station_id': 'bcycle_greenbikeslc_4619'},
#  {'lon': -111.97083,
#   'lat': 41.21869,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7277&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7277&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'region_id': 'bcycle_greenbikeslc_region_37',
#   'address': '26th St and Washington Blvd',
#   'name': '26th St and Washington Blvd',
#   'station_id': 'bcycle_greenbikeslc_7277'},
#  {'lon': -111.97073,
#   'lat': 41.22477,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7278&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7278&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'region_id': 'bcycle_greenbikeslc_region_37',
#   'address': '23rd St and Washington Blvd',
#   'name': '23rd St and Washington Blvd',
#   'station_id': 'bcycle_greenbikeslc_7278'},
#  {'lon': -111.9763,
#   'lat': 41.22044,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7279&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7279&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'region_id': 'bcycle_greenbikeslc_region_37',
#   'address': '25th St and Lincoln Ave',
#   'name': '25th St and Lincoln Ave',
#   'station_id': 'bcycle_greenbikeslc_7279'},
#  {'lon': -111.98023,
#   'lat': 41.22412,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7280&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7280&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'region_id': 'bcycle_greenbikeslc_region_37',
#   'address': '2350 Wall Ave',
#   'name': 'Frontrunner Station @ 2350 Wall Ave',
#   'station_id': 'bcycle_greenbikeslc_7280'},
#  {'lon': -111.97321,
#   'lat': 41.22924,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7283&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7283&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'region_id': 'bcycle_greenbikeslc_region_37',
#   'address': '21st and Grant Ave',
#   'name': '21st St and Grant Ave',
#   'station_id': 'bcycle_greenbikeslc_7283'},
#  {'lon': -111.97293,
#   'lat': 41.23282,
#   'rental_uris': {'ios': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7284&platform=iOS',
#    'android': 'https://www.bcycle.com/applink?system_id=bcycle_greenbikeslc&station_id=bcycle_greenbikeslc_7284&platform=android'},
#   '_bcycle_station_type': 'Kiosk and Station',
#   'region_id': 'bcycle_greenbikeslc_region_37',
#   'address': '1911 S 315 E',
#   'name': 'Brewery @ Grant Ave and Park Blvd',
#   'station_id': 'bcycle_greenbikeslc_7284'}]

# %%
# Just in case we can't get the live GBFS data during the presention, this loads
# it from a local snapshot instead.
from gbfs.client import GBFSClient
from gbfs.data.fetchers import LocalJSONFetcher
client = GBFSClient(url="gbfs_snapshot/gbfs.json", json_fetcher=LocalJSONFetcher())
gbfs_stations = client.request_feed('station_information').get('data').get('stations')

# %% [markdown]
# **Option 2:** Use the `pybikes` Python package: https://github.com/eskerda/PyBikes

# %%
import pybikes
system_info = pybikes.get('bicing')
system_info.update()

for station in system_info.stations:
    print(f"{station.name:80}{station.free:>2}")

# %% [markdown]
# **After either option:** Store station info in convenient data structure

# %%
from typing import NamedTuple

class Station(NamedTuple):
    lat: float
    lon: float
    name: str
    id: str

    @property
    def lonlat(self):
        return self.lon, self.lat
       
    @property
    def latlon(self):
        return self.lat, self.lon
        
    def __repr__(self):
        return (
            f"{self.lat:9.5f} {self.lon:9.5f} {self.id:5} {self.name[:40]}")

# %%
stations = [
    Station(
        lat=station["lat"],
        lon=station["lon"],
        name=station["name"],
        id=int(station["station_id"].split("_")[-1]), 
        # e.g. "bcycle_greenbikeslc_1234"
    ) 
    for station in gbfs_stations
    if station.get("region_id") == None  # None = SLC, 13 = Ogden
]
# Out:
# [ 40.76704 -111.88774  2248 Harmons Station @ 123E 100S,
#   40.76903 -111.89126  2251 Key Bank Station @ 6S Main Street,
#   40.76266 -111.89544  2252 Squatters Station @ 147W Broadway,
#   40.76812 -111.89419  2254 20S West Temple Station,
#   40.76142 -111.89091  2255 City Weekly Station @ 353S Main Street,
#   40.76975 -111.90274  2256 400W South Temple Station,
#   40.76430 -111.89095  2257 Rocky Mountain Power Station @ 225S Main,
#   40.77181 -111.89667  2258 The Church of Jesus Christ of Latter-Day,
#   40.76257 -111.90850  2259 UTA Salt Lake Central Station @ 290S 600,
#   40.76906 -111.89707  2400 Radisson Station @ 215W South Temple,
#   40.75943 -111.88521  2735 UCAIR Station @ 450S 200E,
#   40.77132 -111.90874  2736 640W  North Temple Station,
#   40.76624 -111.89124  2737 Energy Development Station @ 136S Main S,
#   40.75861 -111.89593  2738 Sheraton Station @ 500S 150W,
#   40.76539 -111.87982  2739 CityScape Station @ 190S 400E,
#   40.76297 -111.88286  2740 3 & 3 Uncommons Station ,
#   40.76283 -111.89248  2742 Twilight Concert Series Station @ 50W Br,
#   40.76285 -111.90006  3181 UCAIR Station @ Pioneer Park,
#   40.76524 -111.88515  3182 SLUG Mag Station @ 200S 200E,
#   40.76713 -111.90424  3183 The Gateway Station @ 100S Rio Grande ,
#   40.76746 -111.87664  3184  100S 500E Station,
#   40.76307 -111.87697  3185 JF Capital Station @ 300S 500E,
#   40.76732 -111.89085  3423 Dominion Energy Station @ 100S Main Stre,
#   40.76377 -111.89659  3425 250S 200W Station,
#   40.76485 -111.89817  3426 Milagro and AC Hotel Station @ 200S 250W,
#   40.75791 -111.87152  3427 Salt Lake Mag Station @ 510S 700E (Troll,
#   40.77187 -111.90500  3428 UTA FrontRunner Station @ 500W North Tem,
#   40.76464 -111.91133  3430 UTA FrontLines Station @ 200S 669W,
#   40.76474 -111.90558  3847 Artspace Bridge Station @ 200S 500W,
#   40.72529 -111.89756  4524 UTA Central Pointe Station @ 2100S 225W,
#   40.72739 -111.88739  4525 Salt Lake County Station @ 2001S State S,
#   40.74988 -111.86563  4526 9th & 9th Station,
#   40.75174 -111.90271  4528 Artspace Commons Station @ 800S 400W,
#   40.75025 -111.89094  4529 Proper Brewing Co Station @ 867S Main St,
#   40.76833 -111.90529  4530 50S 500W Station,
#   40.75940 -111.88244  4590 The Shop @ 450S 300E Station,
#   40.75689 -111.90523  4591 EcoBox Station @ 580S 500W ,
#   40.77187 -111.89126  4593 The Church of Jesus Christ of Latter-Day,
#   40.74991 -111.87725  4594 900S 490E Station,
#   40.76296 -111.87053  4595 300S 710E Station,
#   40.76265 -111.88568  4603 300S 200E Station,
#   40.76154 -111.88511  4619 349S 200E Station]

# %%
# As of Oct 2022, there are 42 stations in SLC (and 6 more in Ogden that 
# get filtered out above)

len(stations)
# Out:
# 42

# %% [markdown]
# # Step 2: Folium for Mapping
#
# Folium on PyPI: https://pypi.org/project/folium/

# %%
import folium

def basemap(stations: list[Station]) -> folium.Map:
    center_lat = 0.5 * (min(st.lat for st in stations) + max(st.lat for st in stations))
    center_lon = 0.5 * (min(st.lon for st in stations) + max(st.lon for st in stations))
    
    mymap = folium.Map(
        location=[center_lat, center_lon], 
        zoom_start=13,
        tiles='CartoDB positron',  # other options: Stamen Terrain, Stamen Toner (high contrast)
    )

    for idx, st in enumerate(stations):
        folium.Circle(
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=1.0,
            location=st.latlon, 
            radius=30,
            popup=f"<strong>#{idx}&nbsp;({st.id})</strong> {st.name}",
        ).add_to(mymap)
        
    return mymap

# %%
basemap(stations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e71ed55655dc19b5eea7ac1dc417d08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e71ed55655dc19b5eea7ac1dc417d08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8e71ed55655dc19b5eea7ac1dc417d08 = L.map(
#                 &quot;map_8e71ed55655dc19b5eea7ac1dc417d08&quot;,
#                 {
#                     center: [40.748580000000004, -111.88848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24480939cca4d6c8303eea97fe2cc59c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e71ed55655dc19b5eea7ac1dc417d08);
#
#
#             var circle_e93075d5825af3657800fbd8727704e6 = L.circle(
#                 [40.76704, -111.88774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e71ed55655dc19b5eea7ac1dc417d08);
#
#
#         var popup_a78639b752710d5a4a2eb4e2085a85de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9228e5d4b2d9c2ed25d19f68586dfe4f = $(`&lt;div id=&quot;html_9228e5d4b2d9c2ed25d19f68586dfe4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#0&amp;nbsp;(2248)&lt;/strong&gt; Harmons Station @ 123E 100S&lt;/div&gt;`)[0];
#                 popup_a78639b752710d5a4a2eb4e2085a85de.setContent(html_9228e5d4b2d9c2ed25d19f68586dfe4f);
#
#
#
#         circle_e93075d5825af3657800fbd8727704e6.bindPopup(popup_a78639b752710d5a4a2eb4e2085a85de)
#         ;
#
#
#
#
#             var circle_bd57619ba4017b121f63587570a8f1a8 = L.circle(
#                 [40.76903, -111.89126],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e71ed55655dc19b5eea7ac1dc417d08);
#
#
#         var popup_74ab5ef40cd03bebdedfdd76a4d32a21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cc86487c46b20905870dd6b28776580 = $(`&lt;div id=&quot;html_5cc86487c46b20905870dd6b28776580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#1&amp;nbsp;(2251)&lt;/strong&gt; Key Bank Station @ 6S Main Street&lt;/div&gt;`)[0];
#                 popup_74ab5ef40cd03bebdedfdd76a4d32a21.setContent(html_5cc86487c46b20905870dd6b28776580);
#
#
#
#         circle_bd57619ba4017b121f63587570a8f1a8.bindPopup(popup_74ab5ef40cd03bebdedfdd76a4d32a21)
#         ;
#
#
#
#
#             var circle_364d24c22f8184fc53ef67bc77ea01c5 = L.circle(
#                 [40.76266, -111.89544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8e71ed55655dc19b5eea7ac1dc417d08);
#
#
#         var popup_3c144794053b3f72cbab687c4386bb22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72c1184d96cd1d04bfdcb071a38adca3 = $(`&lt;div id=&quot;html_72c1184d96cd1d04bfdcb071a38adca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#2&amp;nbsp;(2252)&lt;/strong&gt; Squatters Station @ 147W Broadway&lt;/div&gt;`)[0];
#                 popup_3c144794053b3f72cbab687c4386bb22.setContent(html_72c1184d96cd1d04bfdcb071a38adca3);
#
#
#
#         circle_364d24c22f8184fc53ef67bc77ea01c5.bindPopup(popup_3c144794053b3f72cbab687c4386bb22)
#         ;
#
#
#
#
#             var circle_68e03d07d1795ba03f2099b190f58821 = L.circle(
#                 [40.76812, -111.89419],
#                 {&quot;bubblingMouseE

# %% [markdown]
# The distance calculator is approximately 1% of the feature set of geopy, but here we go: https://pypi.org/project/geopy/

# %%
from geopy.distance import distance
from functools import cache

@cache
def as_the_bird_flies(from_station: Station, to_station: Station):
    """Returns distance between two stations in whole meters"""
    dist = distance(from_station.latlon, to_station.latlon)
    return int(dist.meters)

# %%
distance_26_to_29 = as_the_bird_flies(stations[26], stations[29]) / 1609
# Out:
# 3.238036047234307

# %%
mymap = basemap(stations)
line = folium.PolyLine([stations[26].latlon, stations[29].latlon, stations[15].latlon])
line.add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c93cc44886f4101e511afce0003aebe4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c93cc44886f4101e511afce0003aebe4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c93cc44886f4101e511afce0003aebe4 = L.map(
#                 &quot;map_c93cc44886f4101e511afce0003aebe4&quot;,
#                 {
#                     center: [40.748580000000004, -111.88848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ef3543365fecaca567686693750cdb2 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c93cc44886f4101e511afce0003aebe4);
#
#
#             var circle_1e3385275edecea2a1be6c3ec4378c15 = L.circle(
#                 [40.76704, -111.88774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c93cc44886f4101e511afce0003aebe4);
#
#
#         var popup_5a63b94d8a1dd85336bbfa36616bbc9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e12a066758ad35898eb26f5a5075fd8 = $(`&lt;div id=&quot;html_1e12a066758ad35898eb26f5a5075fd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#0&amp;nbsp;(2248)&lt;/strong&gt; Harmons Station @ 123E 100S&lt;/div&gt;`)[0];
#                 popup_5a63b94d8a1dd85336bbfa36616bbc9c.setContent(html_1e12a066758ad35898eb26f5a5075fd8);
#
#
#
#         circle_1e3385275edecea2a1be6c3ec4378c15.bindPopup(popup_5a63b94d8a1dd85336bbfa36616bbc9c)
#         ;
#
#
#
#
#             var circle_9a860b9c11246a058b79c43040a9434a = L.circle(
#                 [40.76903, -111.89126],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c93cc44886f4101e511afce0003aebe4);
#
#
#         var popup_344d306cf2ed5a1bd4646640cb7f1182 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cf0c4bfcac27bef91c8c18343e8bdd4 = $(`&lt;div id=&quot;html_9cf0c4bfcac27bef91c8c18343e8bdd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#1&amp;nbsp;(2251)&lt;/strong&gt; Key Bank Station @ 6S Main Street&lt;/div&gt;`)[0];
#                 popup_344d306cf2ed5a1bd4646640cb7f1182.setContent(html_9cf0c4bfcac27bef91c8c18343e8bdd4);
#
#
#
#         circle_9a860b9c11246a058b79c43040a9434a.bindPopup(popup_344d306cf2ed5a1bd4646640cb7f1182)
#         ;
#
#
#
#
#             var circle_46832bd8d2f8a5f55a51a19ec5aeddb2 = L.circle(
#                 [40.76266, -111.89544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c93cc44886f4101e511afce0003aebe4);
#
#
#         var popup_be342c9b75a4dbcb630442de85838d5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87641ee25e255b5e1ac90e07a67ef33a = $(`&lt;div id=&quot;html_87641ee25e255b5e1ac90e07a67ef33a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#2&amp;nbsp;(2252)&lt;/strong&gt; Squatters Station @ 147W Broadway&lt;/div&gt;`)[0];
#                 popup_be342c9b75a4dbcb630442de85838d5a.setContent(html_87641ee25e255b5e1ac90e07a67ef33a);
#
#
#
#         circle_46832bd8d2f8a5f55a51a19ec5aeddb2.bindPopup(popup_be342c9b75a4dbcb630442de85838d5a)
#         ;
#
#
#
#
#             var circle_1d4246cbf7e0c111d4c1258b18c08c1e = L.circle(
#                 [40.76812, -111.89419],
#                 {&quot;bubblingMouseE

# %% [markdown]
# # Step 3: Traveling Salesman with OR-tools
#
# Closely following the "Traveling Salesperson Problem" tutorial: https://developers.google.com/optimization/routing/tsp

# %%
from ortools.constraint_solver.pywrapcp import (
    RoutingIndexManager,
    RoutingModel,
    DefaultRoutingSearchParameters,
)

manager = RoutingIndexManager(
    len(stations), # number of stations
    1,             # number of vehicles
    30,            # index of start/finish station
)
# Out:
# <ortools.constraint_solver.pywrapcp.RoutingIndexManager; proxy of <Swig Object of type 'operations_research::RoutingIndexManager *' at 0x109b5f090> >

# %%
def cost_function(from_index, to_index):
    """Cost function for OR Tools"""
    from_station: Station = stations[manager.IndexToNode(from_index)]
    to_station: Station = stations[manager.IndexToNode(to_index)]
    return as_the_bird_flies(from_station, to_station)

# %%
routing = RoutingModel(manager)
callback_ptr = routing.RegisterTransitCallback(cost_function)
routing.SetArcCostEvaluatorOfAllVehicles(callback_ptr)
search_parameters = DefaultRoutingSearchParameters()
search_parameters.time_limit.seconds = 120

# This line runs the optimization algorithm
solution = routing.SolveWithParameters(search_parameters)

total_dist = solution.ObjectiveValue()
print(f"Distance: {total_dist/1000:.3} km ({total_dist/1609:.3} mi)")
# Out:
# Distance: 22.2 km (13.8 mi)

# %%
import itertools

def index_pair_to_polyline(idx1: int, idx2: int) -> folium.PolyLine:
    """Turn two indices from ORtools into a straight line connecting them"""
    st1 = stations[manager.IndexToNode(idx1)]
    st2 = stations[manager.IndexToNode(idx2)]
    return folium.PolyLine([st1.latlon, st2.latlon])

def route_from_ortools_solution(solution, routing) -> list[folium.PolyLine]:
    """Turn OR-tools solution into list of Folium polylines"""
    indices = [routing.Start(0)]
    while not routing.IsEnd(indices[-1]):
        indices.append(solution.Value(routing.NextVar(indices[-1])))
        
    return [
        index_pair_to_polyline(idx1, idx2) 
        for idx1, idx2 in itertools.pairwise(indices)
    ]
    
def draw_route(list_of_stations, list_of_polylines):
    routemap = basemap(list_of_stations)
    for polyline in list_of_polylines:
        polyline.add_to(routemap)
    return routemap
    
route = route_from_ortools_solution(solution, routing)
draw_route(stations, route)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8722bdd29af7089acdd0773574b20ce3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8722bdd29af7089acdd0773574b20ce3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8722bdd29af7089acdd0773574b20ce3 = L.map(
#                 &quot;map_8722bdd29af7089acdd0773574b20ce3&quot;,
#                 {
#                     center: [40.748580000000004, -111.88848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce6d31f0c8d1f9bbda739cf67c6b9a9b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8722bdd29af7089acdd0773574b20ce3);
#
#
#             var circle_51de46a577cb8a2611771ec87b26bf6b = L.circle(
#                 [40.76704, -111.88774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8722bdd29af7089acdd0773574b20ce3);
#
#
#         var popup_4df13eef901e8f7e0cc6cd1d84a3b2ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23e43594b256e087ac605a481b95793a = $(`&lt;div id=&quot;html_23e43594b256e087ac605a481b95793a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#0&amp;nbsp;(2248)&lt;/strong&gt; Harmons Station @ 123E 100S&lt;/div&gt;`)[0];
#                 popup_4df13eef901e8f7e0cc6cd1d84a3b2ab.setContent(html_23e43594b256e087ac605a481b95793a);
#
#
#
#         circle_51de46a577cb8a2611771ec87b26bf6b.bindPopup(popup_4df13eef901e8f7e0cc6cd1d84a3b2ab)
#         ;
#
#
#
#
#             var circle_8c30a9c9e33ae1c6d9888060b03fa102 = L.circle(
#                 [40.76903, -111.89126],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8722bdd29af7089acdd0773574b20ce3);
#
#
#         var popup_02f0b2d74370046d79c8675c5620c7e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34ca94cf84158c70355eebb45f72e699 = $(`&lt;div id=&quot;html_34ca94cf84158c70355eebb45f72e699&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#1&amp;nbsp;(2251)&lt;/strong&gt; Key Bank Station @ 6S Main Street&lt;/div&gt;`)[0];
#                 popup_02f0b2d74370046d79c8675c5620c7e5.setContent(html_34ca94cf84158c70355eebb45f72e699);
#
#
#
#         circle_8c30a9c9e33ae1c6d9888060b03fa102.bindPopup(popup_02f0b2d74370046d79c8675c5620c7e5)
#         ;
#
#
#
#
#             var circle_46f4c8e534b9fcf0f1622fff8e04817f = L.circle(
#                 [40.76266, -111.89544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8722bdd29af7089acdd0773574b20ce3);
#
#
#         var popup_4850e4a79e6c4fa2344da571676e5609 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c8b71eedd12ecba1cce0f51386a2cf7 = $(`&lt;div id=&quot;html_6c8b71eedd12ecba1cce0f51386a2cf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#2&amp;nbsp;(2252)&lt;/strong&gt; Squatters Station @ 147W Broadway&lt;/div&gt;`)[0];
#                 popup_4850e4a79e6c4fa2344da571676e5609.setContent(html_6c8b71eedd12ecba1cce0f51386a2cf7);
#
#
#
#         circle_46f4c8e534b9fcf0f1622fff8e04817f.bindPopup(popup_4850e4a79e6c4fa2344da571676e5609)
#         ;
#
#
#
#
#             var circle_5cc8c5a5312474fd321b7a2bd03c42cd = L.circle(
#                 [40.76812, -111.89419],
#                 {&quot;bubblingMouseE

# %% [markdown]
# # Step 4: Real cycling directions from Mapbox

# %%
import mapbox
from pathlib import Path
MAPBOX_TOKEN = Path("./mapboxtoken.txt").open().read().strip()
service = mapbox.Directions(access_token=MAPBOX_TOKEN)

# %%
class RouteSegment(NamedTuple):
    distance: float
    duration: float
    polyline: folium.PolyLine

def get_route_from_mapbox(
    from_station: Station, to_station: Station
) -> RouteSegment:
    """Fetch directions from Mapbox API and turn into Folium polyline"""
    resp = service.directions(
        [from_station.lonlat, to_station.lonlat],
        profile="mapbox/cycling",
        geometries="polyline",
    ).geojson()
    
    feature = resp["features"][0]
    coordinates = feature["geometry"]["coordinates"]
    flipped = [(lat, lon) for (lon, lat) in coordinates]
    
    return RouteSegment(
        distance=feature["properties"]["distance"],
        duration=feature["properties"]["duration"],
        polyline=folium.PolyLine(flipped),
    )

# %%
example_route_leg = get_route_from_mapbox(stations[14], stations[15])
# Out:
# RouteSegment(distance=604.1, duration=193.6, polyline=<folium.vector_layers.PolyLine object at 0x10fbabbe0>)

# %%
route_segments: dict[tuple[int, int], RouteSegment] = {}
# Out:
# {}

# %%
import itertools
import time

# For the East Bay version I had a cutoff here: If the straight
# line distance is larger than x miles, don't even bother to get
# the cycling distance. This was to keep the request count to 
# Mapbox low and because I didn't want ORTools to even consider
# route legs that long. However, in SLC that doesn't work: 40
# stations are within a one mile radius anyway, but the other two
# stations are more than a mile and a half away from the others.
# Plus, the requests count will only be 42*41 = 1722. Keeping
# the code here but bumping the cutoff to a large number so that  
# it never applies.
CUTOFF_DISTANCE = 999 * 1609

# permutations() and not combinations() because the directions 
# might be different due to one-way streets, etc.
for from_station, to_station in itertools.permutations(stations, 2):
    
    # use straight line distance to filter out unrealistic station
    # pairs
    straight_line = as_the_bird_flies(from_station, to_station)
    if straight_line > CUTOFF_DISTANCE:
        continue

    # call API to get actual cycling route
    route_segments[(from_station.id, to_station.id)] = (
        get_route_from_mapbox(from_station, to_station)
    )

    # rate limit is 300/min = 5/sec
    time.sleep(0.2)

# %% [markdown]
# # Step 5: Traveling Salesman, take 2

# %%
def cost_function_2(from_index, to_index):
    """Cost function for OR Tools"""
    st1 = stations[manager.IndexToNode(from_index)]
    st2 = stations[manager.IndexToNode(to_index)]
    
    try:
        segment = route_segments[(st1.id, st2.id)]
        return int(segment.duration)  # in seconds
    
    except KeyError:
        # overestimate duration for routes we don't
        # have directions for (we really want to avoid them)
        return as_the_bird_flies(st1, st2) * 5

# %%
routing_2 = RoutingModel(manager)
callback_ptr_2 = routing_2.RegisterTransitCallback(cost_function_2)
routing_2.SetArcCostEvaluatorOfAllVehicles(callback_ptr_2)
search_parameters_2 = DefaultRoutingSearchParameters()
solution_2 = routing_2.SolveWithParameters(search_parameters_2)

total_dist = solution_2.ObjectiveValue()
print(f"Duration: {total_dist/3600:.3} hrs")
# Out:
# Duration: 3.31 hrs

# %%
def index_pair_to_polyline(idx1: int, idx2: int) -> folium.PolyLine:
    """Turn two indices from ORtools into a straight line connecting them"""
    st1 = stations[manager.IndexToNode(idx1)]
    st2 = stations[manager.IndexToNode(idx2)]
    # return folium.PolyLine([st1.latlon, st2.latlon])
    return route_segments[st1.id, st2.id].polyline

route_2 = route_from_ortools_solution(solution_2, routing_2)
draw_route(stations, route_2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c232f43af96ea8e0730d13fabd55d79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c232f43af96ea8e0730d13fabd55d79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6c232f43af96ea8e0730d13fabd55d79 = L.map(
#                 &quot;map_6c232f43af96ea8e0730d13fabd55d79&quot;,
#                 {
#                     center: [40.748580000000004, -111.88848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a6bba36b77a66de8ad1d068d9b0ddac = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c232f43af96ea8e0730d13fabd55d79);
#
#
#             var circle_17d69e19b33997ab7987971e1a033a2b = L.circle(
#                 [40.76704, -111.88774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c232f43af96ea8e0730d13fabd55d79);
#
#
#         var popup_a116d4ea2bff61e9c20f99c91187c2fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72d5878986891bc07c8b16ef95051880 = $(`&lt;div id=&quot;html_72d5878986891bc07c8b16ef95051880&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#0&amp;nbsp;(2248)&lt;/strong&gt; Harmons Station @ 123E 100S&lt;/div&gt;`)[0];
#                 popup_a116d4ea2bff61e9c20f99c91187c2fc.setContent(html_72d5878986891bc07c8b16ef95051880);
#
#
#
#         circle_17d69e19b33997ab7987971e1a033a2b.bindPopup(popup_a116d4ea2bff61e9c20f99c91187c2fc)
#         ;
#
#
#
#
#             var circle_a1120360ca2a3f51110bd04d8c5ccbca = L.circle(
#                 [40.76903, -111.89126],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c232f43af96ea8e0730d13fabd55d79);
#
#
#         var popup_a7f6995dc5d83a14382f3c6d94ef81a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6a4f822097ebe94d8e735c9c03143bd = $(`&lt;div id=&quot;html_e6a4f822097ebe94d8e735c9c03143bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#1&amp;nbsp;(2251)&lt;/strong&gt; Key Bank Station @ 6S Main Street&lt;/div&gt;`)[0];
#                 popup_a7f6995dc5d83a14382f3c6d94ef81a9.setContent(html_e6a4f822097ebe94d8e735c9c03143bd);
#
#
#
#         circle_a1120360ca2a3f51110bd04d8c5ccbca.bindPopup(popup_a7f6995dc5d83a14382f3c6d94ef81a9)
#         ;
#
#
#
#
#             var circle_3412f7fa29bd2f566d5ed388b0210926 = L.circle(
#                 [40.76266, -111.89544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c232f43af96ea8e0730d13fabd55d79);
#
#
#         var popup_b0a80f760d68a2d8dee833c17e176eda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b298d266cdcb98895ffff9c92608f8e3 = $(`&lt;div id=&quot;html_b298d266cdcb98895ffff9c92608f8e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#2&amp;nbsp;(2252)&lt;/strong&gt; Squatters Station @ 147W Broadway&lt;/div&gt;`)[0];
#                 popup_b0a80f760d68a2d8dee833c17e176eda.setContent(html_b298d266cdcb98895ffff9c92608f8e3);
#
#
#
#         circle_3412f7fa29bd2f566d5ed388b0210926.bindPopup(popup_b0a80f760d68a2d8dee833c17e176eda)
#         ;
#
#
#
#
#             var circle_2b789f040fd85c4f52e0be6d51341883 = L.circle(
#                 [40.76812, -111.89419],
#                 {&quot;bubblingMouseE

# %% [markdown]
# Modifying the cost function to penalize rides with durations under 3 minutes a little bit. This cost function considers 3 minutes (180 seconds) ride length the optimum. For example, a two minute ride now has the same cost as a 4 minute ride.

# %%
def cost_function_3(from_index, to_index):
    """Cost function for OR Tools - version 3"""
    st1 = stations[manager.IndexToNode(from_index)]
    st2 = stations[manager.IndexToNode(to_index)]
    
    try:
        segment = route_segments[(st1.id, st2.id)]
        return int(abs(180 - segment.duration))  # in seconds
    
    except KeyError as ex:
        return as_the_bird_flies(st1, st2) * 5

# %%
routing_3 = RoutingModel(manager)
callback_ptr_3 = routing_3.RegisterTransitCallback(cost_function_3)
routing_3.SetArcCostEvaluatorOfAllVehicles(callback_ptr_3)
search_parameters_3 = DefaultRoutingSearchParameters()
solution_3 = routing_3.SolveWithParameters(search_parameters_3)
# Out:
# <ortools.constraint_solver.pywrapcp.Assignment; proxy of <Swig Object of type 'operations_research::Assignment *' at 0x10fba8c90> >

# %%
route_3 = route_from_ortools_solution(solution_3, routing_3)
map_3 = draw_route(stations, route_3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b540327430dd6156775bbd90787c54d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b540327430dd6156775bbd90787c54d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b540327430dd6156775bbd90787c54d5 = L.map(
#                 &quot;map_b540327430dd6156775bbd90787c54d5&quot;,
#                 {
#                     center: [40.748580000000004, -111.88848],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abaf8e9a38d4ee34ea55356184ba74bb = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b540327430dd6156775bbd90787c54d5);
#
#
#             var circle_87ee611ea3552266b3d7c3064d9b24e3 = L.circle(
#                 [40.76704, -111.88774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b540327430dd6156775bbd90787c54d5);
#
#
#         var popup_2ef0b4fc403cfd2301dd06035a7fed35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cef3cd2f6932a0697c01443a1171d7d = $(`&lt;div id=&quot;html_5cef3cd2f6932a0697c01443a1171d7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#0&amp;nbsp;(2248)&lt;/strong&gt; Harmons Station @ 123E 100S&lt;/div&gt;`)[0];
#                 popup_2ef0b4fc403cfd2301dd06035a7fed35.setContent(html_5cef3cd2f6932a0697c01443a1171d7d);
#
#
#
#         circle_87ee611ea3552266b3d7c3064d9b24e3.bindPopup(popup_2ef0b4fc403cfd2301dd06035a7fed35)
#         ;
#
#
#
#
#             var circle_dc6c32ade409a7b1c39faf0d138df132 = L.circle(
#                 [40.76903, -111.89126],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b540327430dd6156775bbd90787c54d5);
#
#
#         var popup_e1e302463d7ebf34231d6bb50f3c9768 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42dbe838d4187c62a4a401171dfd6e2b = $(`&lt;div id=&quot;html_42dbe838d4187c62a4a401171dfd6e2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#1&amp;nbsp;(2251)&lt;/strong&gt; Key Bank Station @ 6S Main Street&lt;/div&gt;`)[0];
#                 popup_e1e302463d7ebf34231d6bb50f3c9768.setContent(html_42dbe838d4187c62a4a401171dfd6e2b);
#
#
#
#         circle_dc6c32ade409a7b1c39faf0d138df132.bindPopup(popup_e1e302463d7ebf34231d6bb50f3c9768)
#         ;
#
#
#
#
#             var circle_9b91f61f6a81ba0b11a171a5a48296bd = L.circle(
#                 [40.76266, -111.89544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b540327430dd6156775bbd90787c54d5);
#
#
#         var popup_65c46d42f0d7febd682f34dbef2ca39b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52f392ee3cd7bacefa3be4785cc72eab = $(`&lt;div id=&quot;html_52f392ee3cd7bacefa3be4785cc72eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;#2&amp;nbsp;(2252)&lt;/strong&gt; Squatters Station @ 147W Broadway&lt;/div&gt;`)[0];
#                 popup_65c46d42f0d7febd682f34dbef2ca39b.setContent(html_52f392ee3cd7bacefa3be4785cc72eab);
#
#
#
#         circle_9b91f61f6a81ba0b11a171a5a48296bd.bindPopup(popup_65c46d42f0d7febd682f34dbef2ca39b)
#         ;
#
#
#
#
#             var circle_c7d3f28057c5cba9ee9961e600003b47 = L.circle(
#                 [40.76812, -111.89419],
#                 {&quot;bubblingMouseE

# %%
map_3.save("extreme-bikeshare-slc-demo.html")
